# %%
import pandas as pd
import pydicom
import numpy as np
# Set the path to the dataset folder
dataset_path = "./cbis-ddsm-dataset/"

# Load the mass case description file
mass_case_description = pd.read_csv(dataset_path + "mass_case_description_train_set.csv")
metadata = pd.read_csv(dataset_path + "metadata.csv")

# %%
mass_case_description["cropped image file path"] = dataset_path + "CBIS-DDSM/" + mass_case_description["cropped image file path"]
mass_case_description["ROI mask file path"] = dataset_path + "CBIS-DDSM/" + mass_case_description["ROI mask file path"]
# Define the regex pattern
pattern = r'(.*/)[^/]*$'

# Extract the directory paths
mass_case_description["directory_path_cropped_image"] = mass_case_description["cropped image file path"].str.extract(pattern)
mass_case_description["directory_path_roi_image"] = mass_case_description["ROI mask file path"].str.extract(pattern)

from glob import glob
from pathlib import Path

# Define a function to find the correct DICOM file in the directory
def find_dicom_file(directory):
    search_path = Path(directory) / "*.dcm"
    dicom_files = glob(str(search_path))

    if len(dicom_files) > 0:
        return dicom_files[0]
    else:
        return None

# Find the actual corresponding file paths
mass_case_description["actual_file_path_cropped"] = mass_case_description["directory_path_cropped_image"].apply(find_dicom_file)
mass_case_description["actual_file_path_roi"] = mass_case_description["directory_path_roi_image"].apply(find_dicom_file)

print(mass_case_description["actual_file_path_cropped"][0], mass_case_description["actual_file_path_roi"][0])

mass_case_description.to_csv("./cbis-ddsm-dataset/updated_mass_case_description_train_set.csv")
# Out:
# cbis-ddsm-dataset/CBIS-DDSM/Mass-Training_P_00001_LEFT_CC_1/1.3.6.1.4.1.9590.100.1.2.108268213011361124203859148071588939106/1.3.6.1.4.1.9590.100.1.2.296736403313792599626368780122205399650/1-2.dcm cbis-ddsm-dataset/CBIS-DDSM/Mass-Training_P_00001_LEFT_CC_1/1.3.6.1.4.1.9590.100.1.2.108268213011361124203859148071588939106/1.3.6.1.4.1.9590.100.1.2.296736403313792599626368780122205399650/1-2.dcm

# %%
import numpy as np
import pandas as pd
import dicomsdl
import os
import re
from concurrent.futures import ThreadPoolExecutor
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
import tensorflow as tf
# from skimage.transform import resize
import cv2
# Load the CSV file
dataset_path = "./cbis-ddsm-dataset/"
mass_case_data = pd.read_csv(dataset_path + "updated_mass_case_description_train_set.csv")

# Define a function to extract image data from a DICOM file
def extract_image_data(file_path):
    dicom_data = dicomsdl.open(file_path)
    image_data = dicom_data.pixelData()
    image_data = cv2.resize(image_data, (512, 512))
    image_data = np.expand_dims(image_data, axis=-1)
    return image_data

# Define a function to extract data from the DataFrame in parallel using multiple threads
def extract_data_parallel(mass_case_data, n_threads=8):
    image_paths = mass_case_data["actual_file_path_cropped"]

    with ThreadPoolExecutor(max_workers=n_threads) as executor:
        images = list(executor.map(extract_image_data, image_paths))

    breast_density = mass_case_data["breast_density"].values
    subtlety = mass_case_data["subtlety"].values
    side = mass_case_data["left or right breast"].values
    view = mass_case_data["image view"].values

    pathology = mass_case_data["pathology"].values
    assessment = mass_case_data["assessment"].values
    shape = mass_case_data["mass shape"].values
    margin = mass_case_data["mass margins"].values

    return images, breast_density, subtlety, side, view, pathology, assessment, shape, margin

# Extract the data using multithreading
images, breast_density, subtlety, side, view, pathology, assessment, shape, margin = extract_data_parallel(mass_case_data)

# %%
tf.__version__
# Out:
# '2.6.0'

# %%
#Setting gpu for limit memory
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    #Restrict Tensorflow to only allocate 6gb of memory on the first GPU
   try:
        tf.config.experimental.set_virtual_device_configuration(gpus[0],
       [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=7392)])
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
   except RuntimeError as e:
       #virtual devices must be set before GPUs have been initialized
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs
# 2023-04-26 07:58:09.629670: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-26 07:58:09.643612: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-26 07:58:09.643749: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-26 07:58:09.657316: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-26 07:58:09.657740: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-26 07:58:09.657922: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-26 07:58:09.658024: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-26 07:58:10.087530: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-26 07:58:10.087688: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-26 07:58:10.087779: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-26 07:58:10.087867: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 7392 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060 Ti, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import mixed_precision
mixed_precision.set_global_policy('mixed_float16')
breast_density_encoder = LabelEncoder()
subtlety_encoder = LabelEncoder()
side_encoder = LabelEncoder()
view_encoder = LabelEncoder()
pathology_encoder = LabelEncoder()
assessment_encoder = LabelEncoder()
shape_encoder = LabelEncoder()
margin_encoder = LabelEncoder()

breast_density_encoded = breast_density_encoder.fit_transform(breast_density)
subtlety_encoded = subtlety_encoder.fit_transform(subtlety)
side_encoded = side_encoder.fit_transform(side)
view_encoded = view_encoder.fit_transform(view)
pathology_encoded = pathology_encoder.fit_transform(pathology)
assessment_encoded = assessment_encoder.fit_transform(assessment)
shape_encoded = shape_encoder.fit_transform(shape)
margin_encoded = margin_encoder.fit_transform(margin)


pathology_one_hot = to_categorical(pathology_encoded)
breast_density_one_hot = to_categorical(breast_density_encoded)
subtlety_one_hot = to_categorical(subtlety_encoded)
side_one_hot = to_categorical(side_encoded)
view_one_hot = to_categorical(view_encoded)
assessment_one_hot = to_categorical(assessment_encoded)
shape_one_hot = to_categorical(shape_encoded)
margin_one_hot = to_categorical(margin_encoded)

# pathology_one_hot = tf.expand_dims(pathology_one_hot, axis=-1)
images = np.array(images, dtype=np.float32) / 255.
print(pathology_one_hot.shape)

(images_train, images_val,
 side_train, side_val,
 view_train, view_val,
 breast_density_train, breast_density_val,
 subtlety_train, subtlety_val,
 pathology_train, pathology_val,
 assessment_train, assessment_val,
 shape_train, shape_val,
 margin_train, margin_val) = train_test_split(images, side_one_hot, view_one_hot, breast_density_one_hot, subtlety_one_hot,
                                              pathology_one_hot, assessment_one_hot, shape_one_hot, margin_one_hot,
                                              test_size=0.2, random_state=42)

print(pathology_train.shape, assessment_train.shape, shape_train.shape, margin_train.shape)
train_dataset = tf.data.Dataset.from_tensor_slices(((images_train, side_train, view_train, breast_density_train, subtlety_train),
            (pathology_train, assessment_train, shape_train, margin_train))).shuffle(buffer_size=1000).batch(32).cache().prefetch(tf.data.AUTOTUNE)
val_dataset = tf.data.Dataset.from_tensor_slices(((images_val, side_val, view_val, breast_density_val, subtlety_val),
            (pathology_val, assessment_val, shape_val, margin_val))).batch(32).cache().prefetch(tf.data.AUTOTUNE)
# Out:
# INFO:tensorflow:Mixed precision compatibility check (mixed_float16): OK
# Your GPU will likely run quickly with dtype policy mixed_float16 as it has compute capability of at least 7.0. Your GPU: NVIDIA GeForce RTX 3060 Ti, compute capability 8.6
# 2023-04-26 07:58:13.232570: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# (1318, 3)
# (1054, 3) (1054, 6) (1054, 19) (1054, 16)
# 2023-04-26 07:58:13.751798: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 1105199104 exceeds 10% of free system memory.
# 2023-04-26 07:58:14.233481: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 1105199104 exceeds 10% of free system memory.

# %%
len(train_dataset)
# Out:
# 33

# %%
from keras.callbacks import TensorBoard, ModelCheckpoint

tensorboard_callback = TensorBoard(log_dir='./logs', histogram_freq=1)

checkpoint_callback = ModelCheckpoint(
    filepath='./checkpoints/model_checkpoint_{epoch:02d}',
    monitor='val_loss',
    save_best_only=True,
    save_weights_only=False,
    mode='min',
    verbose=1
)

callbacks = [tensorboard_callback, checkpoint_callback]
# Out:
# 2023-04-26 07:58:35.813706: I tensorflow/core/profiler/lib/profiler_session.cc:131] Profiler session initializing.
# 2023-04-26 07:58:35.813731: I tensorflow/core/profiler/lib/profiler_session.cc:146] Profiler session started.
# 2023-04-26 07:58:35.813770: I tensorflow/core/profiler/internal/gpu/cupti_tracer.cc:1614] Profiler found 1 GPUs
# 2023-04-26 07:58:35.814786: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcupti.so.11.2'; dlerror: libcupti.so.11.2: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/lib/python3.8/dist-packages/cv2/../../lib64:/usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2023-04-26 07:58:36.029063: I tensorflow/core/profiler/lib/profiler_session.cc:164] Profiler session tear down.
# 2023-04-26 07:58:36.029206: I tensorflow/core/profiler/internal/gpu/cupti_tracer.cc:1748] CUPTI activity buffer flushed

# %%
import tensorflow as tf
from tensorflow.keras import layers, Model
# Define the custom model
class MultiInputMultiOutputModel(tf.keras.Model):
    def __init__(self):
        super(MultiInputMultiOutputModel, self).__init__()
        self.conv1 = layers.Conv2D(32, (3, 3), activation='relu', input_shape=(512, 512, 1))
        self.pool1 = layers.MaxPooling2D((2, 2))
        self.conv2 = layers.Conv2D(64, (3, 3), activation='relu')
        self.pool2 = layers.MaxPooling2D((2, 2))
        self.flatten = layers.Flatten()
        self.dense1 = layers.Dense(64, activation='relu')
        self.dropout = layers.Dropout(0.5)
        self.dense2 = layers.Dense(32, activation='relu')
        self.dense3 = layers.Dense(128, activation="relu")
        self.pathology_output = layers.Dense(3, activation='softmax', dtype='float32', name='pathology_output')
        self.assessment_output = layers.Dense(6, activation='softmax', dtype='float32', name='assessment_output')
        self.shape_output = layers.Dense(19, activation='softmax', dtype='float32', name='shape_output')
        self.margin_output = layers.Dense(16, activation='softmax', dtype='float32', name='margin_output')

    def call(self, inputs):
        images, side, view, breast_density, subtlety = inputs
        x = self.conv1(images)
        x = self.pool1(x)
        x = self.conv2(x)
        x = self.pool2(x)
        x = self.flatten(x)
        
        # side = tf.cast(side, tf.float32)
        # view = tf.cast(view, tf.float32)
        # breast_density = tf.cast(breast_density, tf.float32)
        # subtlety = tf.cast(subtlety, tf.float32)

        x = tf.concat([x, side, view, breast_density, subtlety], axis=-1)
        x = self.dense2(x)
        x = self.dense1(x)
        x = self.dense3(x)

        pathology_output = self.pathology_output(x)
        assessment_output = self.assessment_output(x)
        shape_output = self.shape_output(x)
        margin_output = self.margin_output(x)

        return [pathology_output , assessment_output, shape_output, margin_output]

# Instantiate the custom model
model = MultiInputMultiOutputModel()

# Compile the model
model.compile(optimizer=tf.keras.optimizers.Adam(),
              loss=tf.keras.losses.categorical_crossentropy,
              metrics=['accuracy'])

# %%
history = model.fit(train_dataset, batch_size=8, validation_batch_size=8, validation_data=val_dataset, epochs=20, steps_per_epoch=len(train_dataset),
                    validation_steps=len(val_dataset), callbacks=callbacks)
# Out:
# 2023-04-26 07:59:05.924643: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 1105199104 exceeds 10% of free system memory.
# 2023-04-26 07:59:06.452294: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 1105199104 exceeds 10% of free system memory.
# Epoch 1/20
# 2023-04-26 07:59:07.690211: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# 2023-04-26 07:59:08.325381: E tensorflow/stream_executor/cuda/cuda_dnn.cc:374] Could not create cudnn handle: CUDNN_STATUS_NOT_INITIALIZED
# 2023-04-26 07:59:08.325609: E tensorflow/stream_executor/cuda/cuda_dnn.cc:382] Possibly insufficient driver version: 525.105.17
# 2023-04-26 07:59:08.326166: E tensorflow/stream_executor/cuda/cuda_dnn.cc:374] Could not create cudnn handle: CUDNN_STATUS_INTERNAL_ERROR
# ---------------------------------------------------------------------------
# UnknownError                              Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 history = model.fit(train_dataset, batch_size=8, validation_batch_size=8, validation_data=val_dataset, epochs=20, steps_per_epoch=len(train_dataset),
#       2                     validation_steps=len(val_dataset), callbacks=callbacks)
#
# File /usr/local/lib/python3.8/dist-packages/keras/engine/training.py:1184, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1177 with tf.profiler.experimental.Trace(
#    1178     'train',
#    1179     epoch_num=epoch,
#    1180     step_num=step,
#    1181     batch_size=batch_size,
#    1182     _r=1):
#    1183   callbacks.on_train_batch_begin(step)
# -> 1184   tmp_logs = self.train_function(iterator)
#    1185   if data_handler.should_sync:
#    1186     context.async_wait()
#
# File /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/def_function.py:885, in Function.__call__(self, *args, **kwds)
#     882 compiler = "xla" if self._jit_compile else "nonXla"
#     884 with OptionalXlaContext(self._jit_compile):
# --> 885   result = self._call(*args, **kwds)
#     887 new_tracing_count = self.experimental_get_tracing_count()
#     888 without_tracing = (tracing_count == new_tracing_count)
#
# File /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/def_function.py:950, in Function._call(self, *args, **kwds)
#     946     pass  # Fall through to cond-based initialization.
#     947   else:
#     948     # Lifting succeeded, so variables are initialized and we can run the
#     949     # stateless function.
# --> 950     return self._stateless_fn(*args, **kwds)
#     951 else:
#     952   _, _, _, filtered_flat_args = \
#     953       self._stateful_fn._function_spec.canonicalize_function_inputs(  # pylint: disable=protected-access
#     954           *args, **kwds)
#
# File /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/function.py:3039, in Function.__call__(self, *args, **kwargs)
#    3036 with self._lock:
#    3037   (graph_function,
#    3038    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 3039 return graph_function._call_flat(
#    3040     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/function.py:1963, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1959 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1960 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1961     and executing_eagerly):
#    1962   # No tape is watching; skip to running the function.
# -> 1963   return self._build_call_outputs(self._inference_function.call(
#    1964       ctx, args, cancellation_manager=cancellation_manager))
#    1965 forward_backward = self._select_forward_and_backward_functions(
#    1966     args,
#    1967     possible_gradient_type,
#    1968     executing_eagerly)
#    1969 forward_function, args_with_tangents = forward_backward.forward()
#
# File /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/function.py:591, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     589 with _InterpolateFunctionError(self):
#     590   if cancellation_manager is None:
# --> 591     outputs = execute.execute(
#     592         str(self.signature.name),
#     593         num_outputs=self._num_outputs,
#     594         inputs=args,
#     595         attrs=attrs,
#     596         ctx=ctx)
#     597   else:
#     598     outputs = execute.execute_with_cancellation(
#     599         str(self.signature.name),
#     600         num_outputs=self._num_outputs,
#    (...)
#     603         ctx=ctx,
#     604         cancellation_manager=cancellation_manager)
#
# File /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/execute.py:59, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57 try:
#      58   ctx.ensure_initialized()
# ---> 59   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                       inputs, attrs, num_outputs)
#      61 except core._NotOkStatusException as e:
#      62   if name is not None:
#
# UnknownError:  Failed to get convolution algorithm. This is probably because cuDNN failed to initialize, so try looking to see if a warning log message was printed above.
# 	 [[node multi_input_multi_output_model/conv2d/Conv2D (defined at tmp/ipykernel_1501/1238435592.py:23) ]] [Op:__inference_train_function_2640]
#
# Errors may have originated from an input operation.
# Input Source operations connected to node multi_input_multi_output_model/conv2d/Conv2D:
#  multi_input_multi_output_model/Cast (defined at tmp/ipykernel_1501/694485789.py:1)
#
# Function call stack:
# train_function

# %%
model.summary()
# Out:
# Model: "multi_input_multi_output_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             multiple                  320
#
#  max_pooling2d (MaxPooling2D  multiple                 0
#  )
#
#  conv2d_1 (Conv2D)           multiple                  18496
#
#  max_pooling2d_1 (MaxPooling  multiple                 0
#  2D)
#
#  flatten (Flatten)           multiple                  0
#
#  dense (Dense)               multiple                  2112
#
#  dropout (Dropout)           multiple                  0 (unused)
#
#  dense_1 (Dense)             multiple                  32514528
#
#  dense_2 (Dense)             multiple                  8320
#
#  pathology_output (Dense)    multiple                  387
#
#  assessment_output (Dense)   multiple                  774
#
#  shape_output (Dense)        multiple                  2451
#
#  margin_output (Dense)       multiple                  2064
#
# =================================================================
# Total params: 32,549,452
# Trainable params: 32,549,452
# Non-trainable params: 0
# _________________________________________________________________

# %%
checkpoint_callback_1 = ModelCheckpoint(
    filepath='./checkpoints/model_1_checkpoint_{epoch:02d}.hdf5',
    monitor='val_loss',
    save_best_only=True,
    save_weights_only=False,
    mode='min',
    verbose=1
)

callbacks=[tensorboard_callback, checkpoint_callback_1]

# %%
import tensorflow as tf
from tensorflow.keras import layers, Model
tf.keras.backend.clear_session()
# Define the custom model
class MultiInputMultiOutputModel_V2B0(tf.keras.Model):
    def __init__(self):
        super(MultiInputMultiOutputModel_V2B0, self).__init__()
        self.input_layer = layers.InputLayer(input_shape=((512,512,1)))
        self.eff_layer = tf.keras.applications.efficientnet_v2.EfficientNetV2B3(include_top=False, trainable=False)     
        
        self.global_avg = layers.GlobalAveragePooling2D()
        self.dense1 = layers.Dense(64, activation='relu')
        self.dropout = layers.Dropout(0.5)
        self.dense2 = layers.Dense(32, activation='relu')
        
        self.pathology_output = layers.Dense(3, activation='softmax', name='pathology_output')
        self.assessment_output = layers.Dense(6, activation='softmax', name='assessment_output')
        self.shape_output = layers.Dense(19, activation='softmax', name='shape_output')
        self.margin_output = layers.Dense(16, activation='softmax', name='margin_output')
        self.eff_layer.trainable = False
        

    def call(self, inputs):
        images, side, view, breast_density, subtlety = inputs
        x = self.input_layer(images)
        x = self.eff_layer(x)
        x = self.global_avg(x)
        
        # side = tf.cast(side, tf.float32)
        # view = tf.cast(view, tf.float32)
        # breast_density = tf.cast(breast_density, tf.float32)
        # subtlety = tf.cast(subtlety, tf.float32)

        x = tf.concat([x, side, view, breast_density, subtlety], axis=-1)
        # x = self.batchnormal(x)
        x = self.dense1(x)
        x = self.dropout(x)
        x = self.dense2(x)

        pathology_output = self.pathology_output(x)
        assessment_output = self.assessment_output(x)
        shape_output = self.shape_output(x)
        margin_output = self.margin_output(x)

        return [pathology_output , assessment_output, shape_output, margin_output]

# Instantiate the custom model
model_1 = MultiInputMultiOutputModel_V2B0()

# Compile the model
model_1.compile(optimizer=tf.keras.optimizers.Adam(),
              loss=tf.keras.losses.categorical_crossentropy,
              metrics=['accuracy'])

# %%
model_1_history = model_1.fit(train_dataset, batch_size=8, validation_batch_size=8, validation_data=val_dataset, epochs=20, callbacks=callbacks)

# %%
# # pathology_one_hot = tf.expand_dims(pathology_one_hot, axis=-1)
# images = np.array(images, dtype=np.float32) / 255.
# print(pathology_one_hot.shape)

# (images_train, images_val,
#  side_train, side_val,
#  view_train, view_val,
#  breast_density_train, breast_density_val,
#  subtlety_train, subtlety_val,
#  pathology_train, pathology_val,
#  assessment_train, assessment_val,
#  shape_train, shape_val,
#  margin_train, margin_val) = train_test_split(images, side_one_hot, view_one_hot, breast_density_one_hot, subtlety_one_hot,
#                                               pathology_one_hot, assessment_one_hot, shape_one_hot, margin_one_hot,
#                                               test_size=0.2, random_state=42)

# print(pathology_train.shape, assessment_train.shape, shape_train.shape, margin_train.shape)
# train_dataset = tf.data.Dataset.from_tensor_slices(((images_train, side_train, view_train, breast_density_train, subtlety_train),
#             (pathology_train, assessment_train, shape_train, margin_train))).shuffle(buffer_size=1000).batch(32).cache().prefetch(tf.data.AUTOTUNE)
# val_dataset = tf.data.Dataset.from_tensor_slices(((images_val, side_val, view_val, breast_density_val, subtlety_val),
#             (pathology_val, assessment_val, shape_val, margin_val))).batch(32).cache().prefetch(tf.data.AUTOTUNE)
# Out:
# INFO:tensorflow:Mixed precision compatibility check (mixed_float16): OK
# Your GPU will likely run quickly with dtype policy mixed_float16 as it has compute capability of at least 7.0. Your GPU: NVIDIA GeForce RTX 3060 Ti, compute capability 8.6
# 2023-04-19 22:11:41.071647: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# (1318, 3)
# (1054, 3) (1054, 6) (1054, 19) (1054, 16)

# %%
import numpy as np
import pandas as pd
import dicomsdl
from concurrent.futures import ThreadPoolExecutor
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
import tensorflow as tf
import cv2
tf.keras.mixed_precision.set_global_policy('mixed_float16')
# Load the CSV file
dataset_path = "./cbis-ddsm-dataset/"
mass_case_data = pd.read_csv(dataset_path + "updated_mass_case_description_train_set.csv")

# Define a function to extract image data from a DICOM file
def extract_image_data(file_path):
    dicom_data = dicomsdl.open(file_path)
    image_data = dicom_data.pixelData()
    image_data = cv2.resize(image_data, (512, 512))
    image_data = np.stack([image_data] * 3, axis=-1)
    return image_data

# Define a function to extract data from the DataFrame in parallel using multiple threads
def extract_data_parallel(mass_case_data, n_threads=8):
    image_paths = mass_case_data["actual_file_path_cropped"]

    with ThreadPoolExecutor(max_workers=n_threads) as executor:
        images = list(executor.map(extract_image_data, image_paths))

    breast_density = mass_case_data["breast_density"].values
    subtlety = mass_case_data["subtlety"].values
    side = mass_case_data["left or right breast"].values
    view = mass_case_data["image view"].values

    pathology = mass_case_data["pathology"].values
    assessment = mass_case_data["assessment"].values
    shape = mass_case_data["mass shape"].values
    margin = mass_case_data["mass margins"].values

    return images, breast_density, subtlety, side, view, pathology, assessment, shape, margin

# Extract the data using multithreading
images_1, breast_density, subtlety, side, view, pathology, assessment, shape, margin = extract_data_parallel(mass_case_data)
images_1 = np.array(images_1, dtype=np.float32) / 255.

from tensorflow.keras.utils import to_categorical
from tensorflow.keras import mixed_precision
breast_density_encoder = LabelEncoder()
subtlety_encoder = LabelEncoder()
side_encoder = LabelEncoder()
view_encoder = LabelEncoder()
pathology_encoder = LabelEncoder()
assessment_encoder = LabelEncoder()
shape_encoder = LabelEncoder()
margin_encoder = LabelEncoder()

breast_density_encoded = breast_density_encoder.fit_transform(breast_density)
subtlety_encoded = subtlety_encoder.fit_transform(subtlety)
side_encoded = side_encoder.fit_transform(side)
view_encoded = view_encoder.fit_transform(view)
pathology_encoded = pathology_encoder.fit_transform(pathology)
assessment_encoded = assessment_encoder.fit_transform(assessment)
shape_encoded = shape_encoder.fit_transform(shape)
margin_encoded = margin_encoder.fit_transform(margin)


pathology_one_hot = to_categorical(pathology_encoded)
breast_density_one_hot = to_categorical(breast_density_encoded)
subtlety_one_hot = to_categorical(subtlety_encoded)
side_one_hot = to_categorical(side_encoded)
view_one_hot = to_categorical(view_encoded)
assessment_one_hot = to_categorical(assessment_encoded)
shape_one_hot = to_categorical(shape_encoded)
margin_one_hot = to_categorical(margin_encoded)

print(images_1.shape)
(images_train, images_val,
 side_train, side_val,
 view_train, view_val,
 breast_density_train, breast_density_val,
 subtlety_train, subtlety_val,
 pathology_train, pathology_val,
 assessment_train, assessment_val,
 shape_train, shape_val,
 margin_train, margin_val) = train_test_split(images_1, side_one_hot, view_one_hot, breast_density_one_hot, subtlety_one_hot,
                                              pathology_one_hot, assessment_one_hot, shape_one_hot, margin_one_hot,
                                              test_size=0.2, random_state=42)

print(pathology_train.shape, assessment_train.shape, shape_train.shape, margin_train.shape)
train_dataset = tf.data.Dataset.from_tensor_slices(((images_train, side_train, view_train, breast_density_train, subtlety_train),
            (pathology_train, assessment_train, shape_train, margin_train))).shuffle(buffer_size=1000).batch(8).cache().prefetch(tf.data.AUTOTUNE)
val_dataset = tf.data.Dataset.from_tensor_slices(((images_val, side_val, view_val, breast_density_val, subtlety_val),
            (pathology_val, assessment_val, shape_val, margin_val))).batch(8).cache().prefetch(tf.data.AUTOTUNE)
# Out:
# 2023-04-25 14:16:43.216415: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-04-25 14:16:43.246415: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# INFO:tensorflow:Mixed precision compatibility check (mixed_float16): OK
# Your GPU will likely run quickly with dtype policy mixed_float16 as it has compute capability of at least 7.0. Your GPU: NVIDIA GeForce RTX 3060 Ti, compute capability 8.6
# 2023-04-25 14:16:44.991075: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-04-25 14:16:45.000008: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-04-25 14:16:45.000331: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-04-25 14:16:45.001407: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# (1318, 512, 512, 3)
# (1054, 3) (1054, 6) (1054, 19) (1054, 16)
# 2023-04-25 14:17:00.177067: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-04-25 14:17:00.177254: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-04-25 14:17:00.177340: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-04-25 14:17:00.736275: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-04-25 14:17:00.736424: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-04-25 14:17:00.736517: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-04-25 14:17:00.736599: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 6080 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060 Ti, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
from vit_keras import vit
import tensorflow as tf

class ViTMultiInputMultiOutputModel(tf.keras.Model):
    def __init__(self):
        super(ViTMultiInputMultiOutputModel, self).__init__()
        
        # Define the ViT model
        self.vit_model = vit.vit_b16(
            image_size=512,
            activation='relu',
            pretrained=True,  # Load pre-trained weights
            include_top=False,  # Do not include the classification head
            pretrained_top=False,  # Do not load pre-trained weights for the classification head
            weights='imagenet21k+imagenet2012',
        )
        
        # Define the other input layers
        self.side = tf.keras.layers.InputLayer(input_shape=(1,))
        self.view = tf.keras.layers.InputLayer(input_shape=(1,))
        self.breast_density = tf.keras.layers.InputLayer(input_shape=(1,))
        self.subtlety = tf.keras.layers.InputLayer(input_shape=(1,))
        
        # Define the dense layers
        self.dense1 = tf.keras.layers.Dense(128, activation='relu')
        self.dense2 = tf.keras.layers.Dense(64, activation='relu')

        # Define the output layers
        self.pathology_output = tf.keras.layers.Dense(3, activation='softmax', name="pathology_output")
        self.assessment_output = tf.keras.layers.Dense(6, activation='softmax', name="assessment_output")
        self.shape_output = tf.keras.layers.Dense(19, activation='softmax', name="shape_output")
        self.margin_output = tf.keras.layers.Dense(16, activation='softmax', name="margin_output")

    def call(self, inputs):
        image, side, view, breast_density, subtlety = inputs

        # Pass the image through the ViT model
        x = self.vit_model(image)

        # Flatten the output of the ViT model
        x = tf.keras.layers.Flatten()(x)

        # Concatenate the other inputs with the output of the ViT model
        x = tf.keras.layers.Concatenate()([x, side, view, breast_density, subtlety])

        # Pass the concatenated inputs through the dense layers
        x = self.dense1(x)
        x = self.dense2(x)

        # Generate the outputs
        pathology_output = self.pathology_output(x)
        assessment_output = self.assessment_output(x)
        shape_output = self.shape_output(x)
        margin_output = self.margin_output(x)

        return pathology_output, assessment_output, shape_output, margin_output
# Out:
# /usr/local/lib/python3.8/dist-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(

# %%
# Create a model instance
model_2 = ViTMultiInputMultiOutputModel()

from keras.callbacks import TensorBoard, ModelCheckpoint
checkpoint_callback_2 = ModelCheckpoint(
    filepath='./checkpoints/model_2_checkpoint_{epoch:02d}.hdf5',
    monitor='val_loss',
    save_best_only=True,
    save_weights_only=False,
    mode='min',
    verbose=1
)

# Define input tensors
image_input = tf.keras.Input(shape=(256, 256, 3), name="image_input")
side_input = tf.keras.Input(shape=(1,), name="side_input")
view_input = tf.keras.Input(shape=(1,), name="view_input")
breast_density_input = tf.keras.Input(shape=(1,), name="breast_density_input")
subtlety_input = tf.keras.Input(shape=(1,), name="subtlety_input")

# Call the model with the input tensors
# Compile the model
model_3.compile(
    optimizer='adam',
    loss=tf.keras.losses.categorical_crossentropy,
    metrics=['accuracy']
)

# Fit the model
history_3 = model_3.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=20,
    batch_size=8,
    validation_batch_size=8,
    callbacks=[tensorboard_callback, checkpoint_callback_2]
)
# Out:
# /usr/local/lib/python3.8/dist-packages/vit_keras/utils.py:81: UserWarning: Resizing position embeddings from 24, 24 to 32, 32
#   warnings.warn(
# Epoch 1/20
# 2023-04-25 14:17:06.333241: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_4' with dtype float and shape [1054,6]
# 	 [[{{node Placeholder/_4}}]]
# 2023-04-25 14:17:06.333630: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_3' with dtype float and shape [1054,4]
# 	 [[{{node Placeholder/_3}}]]
# 2023-04-25 14:17:26.517208: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8600
# 2023-04-25 14:17:37.689697: W tensorflow/tsl/framework/bfc_allocator.cc:485] Allocator (GPU_0_bfc) ran out of memory trying to allocate 192.38MiB (rounded to 201720064)requested by op vi_t_multi_input_multi_output_model/vit-b16/Transformer/encoderblock_1/MultiHeadDotProductAttention_1/Softmax
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2023-04-25 14:17:37.689835: I tensorflow/tsl/framework/bfc_allocator.cc:1039] BFCAllocator dump for GPU_0_bfc
# 2023-04-25 14:17:37.689866: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (256): 	Total Chunks: 143, Chunks in use: 142. 35.8KiB allocated for chunks. 35.5KiB in use in bin. 2.9KiB client-requested in use in bin.
# 2023-04-25 14:17:37.689884: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (512): 	Total Chunks: 11, Chunks in use: 10. 7.0KiB allocated for chunks. 6.2KiB in use in bin. 6.0KiB client-requested in use in bin.
# 2023-04-25 14:17:37.689901: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (1024): 	Total Chunks: 61, Chunks in use: 56. 91.2KiB allocated for chunks. 83.8KiB in use in bin. 83.5KiB client-requested in use in bin.
# 2023-04-25 14:17:37.689918: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (2048): 	Total Chunks: 338, Chunks in use: 338. 1011.2KiB allocated for chunks. 1011.2KiB in use in bin. 1010.6KiB client-requested in use in bin.
# 2023-04-25 14:17:37.689935: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (4096): 	Total Chunks: 24, Chunks in use: 23. 129.5KiB allocated for chunks. 123.5KiB in use in bin. 117.8KiB client-requested in use in bin.
# 2023-04-25 14:17:37.689951: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (8192): 	Total Chunks: 37, Chunks in use: 37. 437.0KiB allocated for chunks. 437.0KiB in use in bin. 436.8KiB client-requested in use in bin.
# 2023-04-25 14:17:37.689968: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (16384): 	Total Chunks: 8, Chunks in use: 8. 156.0KiB allocated for chunks. 156.0KiB in use in bin. 142.0KiB client-requested in use in bin.
# 2023-04-25 14:17:37.689984: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (32768): 	Total Chunks: 9, Chunks in use: 9. 289.5KiB allocated for chunks. 289.5KiB in use in bin. 288.2KiB client-requested in use in bin.
# 2023-04-25 14:17:37.690000: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (65536): 	Total Chunks: 2, Chunks in use: 2. 144.2KiB allocated for chunks. 144.2KiB in use in bin. 144.1KiB client-requested in use in bin.
# 2023-04-25 14:17:37.690016: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (131072): 	Total Chunks: 1, Chunks in use: 1. 195.5KiB allocated for chunks. 195.5KiB in use in bin. 195.5KiB client-requested in use in bin.
# 2023-04-25 14:17:37.690033: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (262144): 	Total Chunks: 2, Chunks in use: 2. 782.0KiB allocated for chunks. 782.0KiB in use in bin. 782.0KiB client-requested in use in bin.
# 2023-04-25 14:17:37.690051: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (524288): 	Total Chunks: 2, Chunks in use: 1. 1.44MiB allocated for chunks. 512.0KiB in use in bin. 391.0KiB client-requested in use in bin.
# 2023-04-25 14:17:37.690069: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (1048576): 	Total Chunks: 48, Chunks in use: 47. 54.38MiB allocated for chunks. 52.88MiB in use in bin. 52.88MiB client-requested in use in bin.
# 2023-04-25 14:17:37.690087: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (2097152): 	Total Chunks: 149, Chunks in use: 149. 338.91MiB allocated for chunks. 338.91MiB in use in bin. 336.38MiB client-requested in use in bin.
# 2023-04-25 14:17:37.690106: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (4194304): 	Total Chunks: 27, Chunks in use: 27. 122.99MiB allocated for chunks. 122.99MiB in use in bin. 118.51MiB client-requested in use in bin.
# 2023-04-25 14:17:37.690124: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (8388608): 	Total Chunks: 85, Chunks in use: 84. 820.99MiB allocated for chunks. 808.97MiB in use in bin. 786.12MiB client-requested in use in bin.
# 2023-04-25 14:17:37.690141: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (16777216): 	Total Chunks: 8, Chunks in use: 8. 186.18MiB allocated for chunks. 186.18MiB in use in bin. 180.18MiB client-requested in use in bin.
# 2023-04-25 14:17:37.690158: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (33554432): 	Total Chunks: 4, Chunks in use: 4. 192.19MiB allocated for chunks. 192.19MiB in use in bin. 192.19MiB client-requested in use in bin.
# 2023-04-25 14:17:37.690174: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (67108864): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-04-25 14:17:37.690194: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (134217728): 	Total Chunks: 2, Chunks in use: 2. 406.23MiB allocated for chunks. 406.23MiB in use in bin. 384.75MiB client-requested in use in bin.
# 2023-04-25 14:17:37.690210: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (268435456): 	Total Chunks: 2, Chunks in use: 2. 3.86GiB allocated for chunks. 3.86GiB in use in bin. 3.86GiB client-requested in use in bin.
# 2023-04-25 14:17:37.690227: I tensorflow/tsl/framework/bfc_allocator.cc:1062] Bin for 192.38MiB was 128.00MiB, Chunk State:
# 2023-04-25 14:17:37.690242: I tensorflow/tsl/framework/bfc_allocator.cc:1075] Next region of size 6375866368
# 2023-04-25 14:17:37.690264: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f72b2000000 of size 3315597312 next 1
# 2023-04-25 14:17:37.690285: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f7377a00000 of size 1280 next 2
# 2023-04-25 14:17:37.690309: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f7377a00500 of size 8448 next 3
# 2023-04-25 14:17:37.690334: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f7377a02600 of size 8448 next 4
# 2023-04-25 14:17:37.690354: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f7377a04700 of size 16896 next 5
# 2023-04-25 14:17:37.690366: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f7377a08900 of size 25344 next 6
# 2023-04-25 14:17:37.690381: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f7377a0ec00 of size 12800 next 7
# 2023-04-25 14:17:37.690395: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f7377a11e00 of size 25344 next 8
# 2023-04-25 14:17:37.690411: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f7377a18100 of size 80128 next 9
# 2023-04-25 14:17:37.690424: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f7377a2ba00 of size 67584 next 10
# 2023-04-25 14:17:37.690440: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f7377a3c200 of size 256 next 11
# 2023-04-25 14:17:37.690454: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f7377a3c300 of size 256 next 12
# 2023-04-25 14:17:37.690467: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f7377a3c400 of size 256 next 13
# 2023-04-25 14:17:37.690481: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f7377a3c500 of size 256 next 14
# 2023-04-25 14:17:37.690497: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f7377a3c600 of size 256 next 15
# 2023-04-25 14:17:37.690509: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f7377a3c700 of size 830472192 next 16
# 2023-04-25 14:17:37.690522: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a923c700 of size 2304 next 17
# 2023-04-25 14:17:37.690534: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a923d000 of size 2304 next 18
# 2023-04-25 14:17:37.690546: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a923d900 of size 4352 next 19
# 2023-04-25 14:17:37.690559: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a923ea00 of size 6400 next 20
# 2023-04-25 14:17:37.690572: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9240300 of size 3328 next 21
# 2023-04-25 14:17:37.690592: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9241000 of size 6400 next 22
# 2023-04-25 14:17:37.690607: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9242900 of size 20224 next 23
# 2023-04-25 14:17:37.690620: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9247800 of size 16896 next 24
# 2023-04-25 14:17:37.690658: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a924ba00 of size 256 next 25
# 2023-04-25 14:17:37.690674: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a924bb00 of size 256 next 26
# 2023-04-25 14:17:37.690686: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a924bc00 of size 256 next 28
# 2023-04-25 14:17:37.690698: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a924bd00 of size 3072 next 29
# 2023-04-25 14:17:37.690711: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a924c900 of size 3072 next 27
# 2023-04-25 14:17:37.690725: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a924d500 of size 256 next 30
# 2023-04-25 14:17:37.690738: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a924d600 of size 256 next 33
# 2023-04-25 14:17:37.690752: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a924d700 of size 4712448 next 31
# 2023-04-25 14:17:37.690766: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a96cbf00 of size 4096 next 269
# 2023-04-25 14:17:37.690778: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a96ccf00 of size 5632 next 265
# 2023-04-25 14:17:37.690791: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a96ce500 of size 4864 next 266
# 2023-04-25 14:17:37.690804: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a96cf800 of size 3072 next 279
# 2023-04-25 14:17:37.690818: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a96d0400 of size 3072 next 280
# 2023-04-25 14:17:37.690835: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a96d1000 of size 3072 next 285
# 2023-04-25 14:17:37.690852: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a96d1c00 of size 3072 next 286
# 2023-04-25 14:17:37.690868: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a96d2800 of size 3072 next 289
# 2023-04-25 14:17:37.690886: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a96d3400 of size 3072 next 290
# 2023-04-25 14:17:37.690913: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a96d4000 of size 3072 next 293
# 2023-04-25 14:17:37.690931: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a96d4c00 of size 3072 next 294
# 2023-04-25 14:17:37.690953: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a96d5800 of size 3072 next 297
# 2023-04-25 14:17:37.690971: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a96d6400 of size 3072 next 298
# 2023-04-25 14:17:37.690994: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a96d7000 of size 20224 next 251
# 2023-04-25 14:17:37.691017: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a96dbf00 of size 32768 next 250
# 2023-04-25 14:17:37.691042: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a96e3f00 of size 12288 next 301
# 2023-04-25 14:17:37.691066: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a96e6f00 of size 3072 next 304
# 2023-04-25 14:17:37.691090: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a96e7b00 of size 3072 next 305
# 2023-04-25 14:17:37.691114: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a96e8700 of size 3072 next 306
# 2023-04-25 14:17:37.691138: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a96e9300 of size 3072 next 307
# 2023-04-25 14:17:37.691162: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a96e9f00 of size 3072 next 308
# 2023-04-25 14:17:37.691185: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a96eab00 of size 3072 next 309
# 2023-04-25 14:17:37.691204: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a96eb700 of size 3072 next 310
# 2023-04-25 14:17:37.691227: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a96ec300 of size 3072 next 311
# 2023-04-25 14:17:37.691249: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a96ecf00 of size 3072 next 312
# 2023-04-25 14:17:37.691273: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a96edb00 of size 3072 next 313
# 2023-04-25 14:17:37.691296: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a96ee700 of size 3072 next 316
# 2023-04-25 14:17:37.691313: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a96ef300 of size 3072 next 317
# 2023-04-25 14:17:37.691336: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a96eff00 of size 3072 next 320
# 2023-04-25 14:17:37.691362: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a96f0b00 of size 3072 next 321
# 2023-04-25 14:17:37.691385: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a96f1700 of size 3072 next 324
# 2023-04-25 14:17:37.691404: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a96f2300 of size 3072 next 325
# 2023-04-25 14:17:37.691426: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a96f2f00 of size 3072 next 328
# 2023-04-25 14:17:37.691447: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a96f3b00 of size 3072 next 329
# 2023-04-25 14:17:37.691464: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a96f4700 of size 12288 next 332
# 2023-04-25 14:17:37.691488: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a96f7700 of size 12288 next 333
# 2023-04-25 14:17:37.691512: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a96fa700 of size 3072 next 336
# 2023-04-25 14:17:37.691529: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a96fb300 of size 3072 next 337
# 2023-04-25 14:17:37.691550: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a96fbf00 of size 3072 next 338
# 2023-04-25 14:17:37.691574: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a96fcb00 of size 3072 next 339
# 2023-04-25 14:17:37.691596: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a96fd700 of size 3072 next 340
# 2023-04-25 14:17:37.691619: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a96fe300 of size 3072 next 341
# 2023-04-25 14:17:37.691643: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a96fef00 of size 3072 next 342
# 2023-04-25 14:17:37.691666: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a96ffb00 of size 3072 next 343
# 2023-04-25 14:17:37.691692: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9700700 of size 3072 next 344
# 2023-04-25 14:17:37.691716: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9701300 of size 3072 next 345
# 2023-04-25 14:17:37.691738: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9701f00 of size 3072 next 348
# 2023-04-25 14:17:37.691762: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9702b00 of size 3072 next 349
# 2023-04-25 14:17:37.691786: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9703700 of size 3072 next 352
# 2023-04-25 14:17:37.691809: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9704300 of size 3072 next 353
# 2023-04-25 14:17:37.691833: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9704f00 of size 3072 next 356
# 2023-04-25 14:17:37.691856: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9705b00 of size 3072 next 357
# 2023-04-25 14:17:37.691879: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9706700 of size 3072 next 360
# 2023-04-25 14:17:37.691902: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9707300 of size 3072 next 361
# 2023-04-25 14:17:37.691925: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9707f00 of size 12288 next 364
# 2023-04-25 14:17:37.691947: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a970af00 of size 12288 next 365
# 2023-04-25 14:17:37.691972: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a970df00 of size 3072 next 368
# 2023-04-25 14:17:37.691996: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a970eb00 of size 3072 next 369
# 2023-04-25 14:17:37.692020: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a970f700 of size 3072 next 370
# 2023-04-25 14:17:37.692043: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9710300 of size 3072 next 371
# 2023-04-25 14:17:37.692067: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9710f00 of size 3072 next 372
# 2023-04-25 14:17:37.692089: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9711b00 of size 3072 next 373
# 2023-04-25 14:17:37.692114: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9712700 of size 3072 next 374
# 2023-04-25 14:17:37.692139: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9713300 of size 3072 next 375
# 2023-04-25 14:17:37.692158: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9713f00 of size 3072 next 376
# 2023-04-25 14:17:37.692181: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9714b00 of size 3072 next 377
# 2023-04-25 14:17:37.692204: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9715700 of size 3072 next 380
# 2023-04-25 14:17:37.692228: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9716300 of size 3072 next 381
# 2023-04-25 14:17:37.692251: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9716f00 of size 3072 next 384
# 2023-04-25 14:17:37.692275: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9717b00 of size 3072 next 385
# 2023-04-25 14:17:37.692298: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9718700 of size 3072 next 388
# 2023-04-25 14:17:37.692317: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9719300 of size 3072 next 389
# 2023-04-25 14:17:37.692340: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9719f00 of size 3072 next 392
# 2023-04-25 14:17:37.692364: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a971ab00 of size 3072 next 393
# 2023-04-25 14:17:37.692387: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a971b700 of size 12288 next 396
# 2023-04-25 14:17:37.692410: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a971e700 of size 12288 next 397
# 2023-04-25 14:17:37.692434: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9721700 of size 3072 next 400
# 2023-04-25 14:17:37.692456: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9722300 of size 3072 next 401
# 2023-04-25 14:17:37.692479: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9722f00 of size 3072 next 402
# 2023-04-25 14:17:37.692503: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9723b00 of size 3072 next 403
# 2023-04-25 14:17:37.692521: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9724700 of size 3072 next 404
# 2023-04-25 14:17:37.692543: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9725300 of size 3072 next 405
# 2023-04-25 14:17:37.692567: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9725f00 of size 3072 next 406
# 2023-04-25 14:17:37.692589: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9726b00 of size 3072 next 407
# 2023-04-25 14:17:37.692608: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9727700 of size 3072 next 408
# 2023-04-25 14:17:37.692631: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9728300 of size 3072 next 409
# 2023-04-25 14:17:37.692656: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9728f00 of size 3072 next 412
# 2023-04-25 14:17:37.692673: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9729b00 of size 3072 next 413
# 2023-04-25 14:17:37.692695: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a972a700 of size 3072 next 416
# 2023-04-25 14:17:37.692715: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a972b300 of size 3072 next 417
# 2023-04-25 14:17:37.692733: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a972bf00 of size 3072 next 420
# 2023-04-25 14:17:37.692752: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a972cb00 of size 3072 next 421
# 2023-04-25 14:17:37.692763: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a972d700 of size 3072 next 424
# 2023-04-25 14:17:37.692773: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a972e300 of size 3072 next 425
# 2023-04-25 14:17:37.692784: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a972ef00 of size 12288 next 428
# 2023-04-25 14:17:37.692799: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9731f00 of size 12288 next 429
# 2023-04-25 14:17:37.692809: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9734f00 of size 3072 next 432
# 2023-04-25 14:17:37.692820: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9735b00 of size 3072 next 433
# 2023-04-25 14:17:37.692831: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9736700 of size 3072 next 434
# 2023-04-25 14:17:37.692841: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9737300 of size 3072 next 435
# 2023-04-25 14:17:37.692852: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9737f00 of size 3072 next 436
# 2023-04-25 14:17:37.692862: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9738b00 of size 3072 next 437
# 2023-04-25 14:17:37.692878: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9739700 of size 3072 next 438
# 2023-04-25 14:17:37.692889: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a973a300 of size 3072 next 439
# 2023-04-25 14:17:37.692899: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a973af00 of size 3072 next 440
# 2023-04-25 14:17:37.692914: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a973bb00 of size 3072 next 441
# 2023-04-25 14:17:37.692925: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a973c700 of size 3072 next 444
# 2023-04-25 14:17:37.692936: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a973d300 of size 3072 next 445
# 2023-04-25 14:17:37.692946: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a973df00 of size 3072 next 448
# 2023-04-25 14:17:37.692957: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a973eb00 of size 3072 next 449
# 2023-04-25 14:17:37.692967: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a973f700 of size 3072 next 452
# 2023-04-25 14:17:37.692982: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9740300 of size 3072 next 453
# 2023-04-25 14:17:37.692993: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9740f00 of size 3072 next 456
# 2023-04-25 14:17:37.693004: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9741b00 of size 3072 next 457
# 2023-04-25 14:17:37.693014: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9742700 of size 12288 next 460
# 2023-04-25 14:17:37.693025: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9745700 of size 12288 next 461
# 2023-04-25 14:17:37.693035: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9748700 of size 3072 next 464
# 2023-04-25 14:17:37.693051: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9749300 of size 3072 next 465
# 2023-04-25 14:17:37.693061: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9749f00 of size 3072 next 466
# 2023-04-25 14:17:37.693072: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a974ab00 of size 3072 next 467
# 2023-04-25 14:17:37.693082: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a974b700 of size 3072 next 468
# 2023-04-25 14:17:37.693093: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a974c300 of size 3072 next 469
# 2023-04-25 14:17:37.693103: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a974cf00 of size 3072 next 470
# 2023-04-25 14:17:37.693118: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a974db00 of size 3072 next 471
# 2023-04-25 14:17:37.693129: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a974e700 of size 3072 next 472
# 2023-04-25 14:17:37.693140: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a974f300 of size 3072 next 473
# 2023-04-25 14:17:37.693150: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a974ff00 of size 3072 next 476
# 2023-04-25 14:17:37.693161: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9750b00 of size 3072 next 477
# 2023-04-25 14:17:37.693178: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9751700 of size 3072 next 480
# 2023-04-25 14:17:37.693188: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9752300 of size 3072 next 481
# 2023-04-25 14:17:37.693199: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9752f00 of size 3072 next 484
# 2023-04-25 14:17:37.693209: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9753b00 of size 3072 next 485
# 2023-04-25 14:17:37.693220: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9754700 of size 3072 next 488
# 2023-04-25 14:17:37.693230: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9755300 of size 3072 next 489
# 2023-04-25 14:17:37.693246: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9755f00 of size 12288 next 492
# 2023-04-25 14:17:37.693256: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9758f00 of size 12288 next 493
# 2023-04-25 14:17:37.693267: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a975bf00 of size 3072 next 496
# 2023-04-25 14:17:37.693277: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a975cb00 of size 3072 next 497
# 2023-04-25 14:17:37.693288: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a975d700 of size 3072 next 498
# 2023-04-25 14:17:37.693299: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a975e300 of size 3072 next 499
# 2023-04-25 14:17:37.693309: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a975ef00 of size 3072 next 500
# 2023-04-25 14:17:37.693324: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a975fb00 of size 3072 next 501
# 2023-04-25 14:17:37.693335: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9760700 of size 3072 next 502
# 2023-04-25 14:17:37.693345: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9761300 of size 3072 next 503
# 2023-04-25 14:17:37.693356: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9761f00 of size 3072 next 504
# 2023-04-25 14:17:37.693366: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9762b00 of size 3072 next 505
# 2023-04-25 14:17:37.693382: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9763700 of size 3072 next 508
# 2023-04-25 14:17:37.693393: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9764300 of size 3072 next 509
# 2023-04-25 14:17:37.693403: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9764f00 of size 3072 next 512
# 2023-04-25 14:17:37.693414: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9765b00 of size 3072 next 513
# 2023-04-25 14:17:37.693429: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9766700 of size 3072 next 516
# 2023-04-25 14:17:37.693440: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9767300 of size 3072 next 517
# 2023-04-25 14:17:37.693451: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9767f00 of size 3072 next 520
# 2023-04-25 14:17:37.693461: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9768b00 of size 3072 next 521
# 2023-04-25 14:17:37.693472: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9769700 of size 12288 next 524
# 2023-04-25 14:17:37.693487: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a976c700 of size 12288 next 525
# 2023-04-25 14:17:37.693498: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a976f700 of size 3072 next 528
# 2023-04-25 14:17:37.693509: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9770300 of size 3072 next 529
# 2023-04-25 14:17:37.693519: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9770f00 of size 3072 next 530
# 2023-04-25 14:17:37.693530: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9771b00 of size 3072 next 531
# 2023-04-25 14:17:37.693545: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9772700 of size 3072 next 532
# 2023-04-25 14:17:37.693555: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9773300 of size 3072 next 533
# 2023-04-25 14:17:37.693578: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9773f00 of size 3072 next 534
# 2023-04-25 14:17:37.693581: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9774b00 of size 3072 next 535
# 2023-04-25 14:17:37.693583: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9775700 of size 3072 next 536
# 2023-04-25 14:17:37.693586: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9776300 of size 3072 next 537
# 2023-04-25 14:17:37.693589: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9776f00 of size 3072 next 540
# 2023-04-25 14:17:37.693592: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9777b00 of size 3072 next 541
# 2023-04-25 14:17:37.693595: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9778700 of size 3072 next 544
# 2023-04-25 14:17:37.693597: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9779300 of size 3072 next 545
# 2023-04-25 14:17:37.693600: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9779f00 of size 3072 next 548
# 2023-04-25 14:17:37.693602: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a977ab00 of size 3072 next 549
# 2023-04-25 14:17:37.693605: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a977b700 of size 3072 next 552
# 2023-04-25 14:17:37.693608: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a977c300 of size 3072 next 553
# 2023-04-25 14:17:37.693611: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a977cf00 of size 12288 next 556
# 2023-04-25 14:17:37.693614: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a977ff00 of size 12288 next 557
# 2023-04-25 14:17:37.693616: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9782f00 of size 3072 next 560
# 2023-04-25 14:17:37.693619: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9783b00 of size 3072 next 561
# 2023-04-25 14:17:37.693622: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9784700 of size 3072 next 562
# 2023-04-25 14:17:37.693625: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9785300 of size 3072 next 563
# 2023-04-25 14:17:37.693627: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9785f00 of size 3072 next 564
# 2023-04-25 14:17:37.693630: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9786b00 of size 3072 next 565
# 2023-04-25 14:17:37.693632: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9787700 of size 3072 next 566
# 2023-04-25 14:17:37.693635: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9788300 of size 3072 next 567
# 2023-04-25 14:17:37.693639: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9788f00 of size 3072 next 568
# 2023-04-25 14:17:37.693641: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9789b00 of size 3072 next 569
# 2023-04-25 14:17:37.693644: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a978a700 of size 3072 next 572
# 2023-04-25 14:17:37.693646: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a978b300 of size 3072 next 573
# 2023-04-25 14:17:37.693649: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a978bf00 of size 3072 next 576
# 2023-04-25 14:17:37.693652: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a978cb00 of size 3072 next 577
# 2023-04-25 14:17:37.693655: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a978d700 of size 3072 next 580
# 2023-04-25 14:17:37.693658: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a978e300 of size 5120 next 246
# 2023-04-25 14:17:37.693661: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a978f700 of size 400384 next 245
# 2023-04-25 14:17:37.693664: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a97f1300 of size 3072 next 583
# 2023-04-25 14:17:37.693667: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a97f1f00 of size 3072 next 584
# 2023-04-25 14:17:37.693669: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a97f2b00 of size 12288 next 587
# 2023-04-25 14:17:37.693672: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a97f5b00 of size 12288 next 588
# 2023-04-25 14:17:37.693674: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a97f8b00 of size 3072 next 591
# 2023-04-25 14:17:37.693677: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a97f9700 of size 3072 next 592
# 2023-04-25 14:17:37.693679: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a97fa300 of size 3072 next 593
# 2023-04-25 14:17:37.693682: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a97faf00 of size 3072 next 594
# 2023-04-25 14:17:37.693684: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a97fbb00 of size 3072 next 595
# 2023-04-25 14:17:37.693687: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a97fc700 of size 3072 next 596
# 2023-04-25 14:17:37.693690: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a97fd300 of size 3072 next 597
# 2023-04-25 14:17:37.693692: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a97fdf00 of size 3072 next 598
# 2023-04-25 14:17:37.693695: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a97feb00 of size 3072 next 599
# 2023-04-25 14:17:37.693697: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a97ff700 of size 3072 next 600
# 2023-04-25 14:17:37.693700: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9800300 of size 3072 next 603
# 2023-04-25 14:17:37.693702: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9800f00 of size 3072 next 604
# 2023-04-25 14:17:37.693705: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9801b00 of size 3072 next 607
# 2023-04-25 14:17:37.693707: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9802700 of size 3072 next 608
# 2023-04-25 14:17:37.693710: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9803300 of size 3072 next 611
# 2023-04-25 14:17:37.693712: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9803f00 of size 3072 next 612
# 2023-04-25 14:17:37.693715: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9804b00 of size 3072 next 615
# 2023-04-25 14:17:37.693717: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9805700 of size 3072 next 616
# 2023-04-25 14:17:37.693720: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9806300 of size 12288 next 619
# 2023-04-25 14:17:37.693723: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9809300 of size 12288 next 620
# 2023-04-25 14:17:37.693725: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a980c300 of size 3072 next 623
# 2023-04-25 14:17:37.693728: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a980cf00 of size 3072 next 624
# 2023-04-25 14:17:37.693731: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a980db00 of size 3072 next 625
# 2023-04-25 14:17:37.693735: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a980e700 of size 3072 next 626
# 2023-04-25 14:17:37.693740: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a980f300 of size 3072 next 627
# 2023-04-25 14:17:37.693746: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a980ff00 of size 3072 next 628
# 2023-04-25 14:17:37.693751: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9810b00 of size 3072 next 629
# 2023-04-25 14:17:37.693756: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9811700 of size 3072 next 630
# 2023-04-25 14:17:37.693762: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9812300 of size 3072 next 631
# 2023-04-25 14:17:37.693768: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9812f00 of size 3072 next 632
# 2023-04-25 14:17:37.693772: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9813b00 of size 3072 next 635
# 2023-04-25 14:17:37.693777: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9814700 of size 3072 next 636
# 2023-04-25 14:17:37.693783: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9815300 of size 3072 next 639
# 2023-04-25 14:17:37.693788: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9815f00 of size 3072 next 640
# 2023-04-25 14:17:37.693794: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9816b00 of size 3072 next 643
# 2023-04-25 14:17:37.693799: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9817700 of size 3072 next 644
# 2023-04-25 14:17:37.693805: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9818300 of size 3072 next 647
# 2023-04-25 14:17:37.693810: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9818f00 of size 3072 next 648
# 2023-04-25 14:17:37.693816: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9819b00 of size 12288 next 651
# 2023-04-25 14:17:37.693822: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a981cb00 of size 12288 next 652
# 2023-04-25 14:17:37.693827: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a981fb00 of size 3072 next 655
# 2023-04-25 14:17:37.693833: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9820700 of size 3072 next 656
# 2023-04-25 14:17:37.693838: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9821300 of size 3072 next 657
# 2023-04-25 14:17:37.693844: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9821f00 of size 3072 next 658
# 2023-04-25 14:17:37.693850: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9822b00 of size 3072 next 659
# 2023-04-25 14:17:37.693855: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9823700 of size 3072 next 660
# 2023-04-25 14:17:37.693861: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9824300 of size 3072 next 661
# 2023-04-25 14:17:37.693866: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9824f00 of size 3072 next 662
# 2023-04-25 14:17:37.693872: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9825b00 of size 3072 next 663
# 2023-04-25 14:17:37.693877: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9826700 of size 3072 next 664
# 2023-04-25 14:17:37.693883: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9827300 of size 3072 next 665
# 2023-04-25 14:17:37.693888: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9827f00 of size 3072 next 666
# 2023-04-25 14:17:37.693894: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9828b00 of size 3072 next 667
# 2023-04-25 14:17:37.693899: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9829700 of size 3072 next 668
# 2023-04-25 14:17:37.693905: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a982a300 of size 400384 next 669
# 2023-04-25 14:17:37.693910: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a988bf00 of size 524288 next 32
# 2023-04-25 14:17:37.693915: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a990bf00 of size 256 next 36
# 2023-04-25 14:17:37.693918: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a990c000 of size 3072 next 37
# 2023-04-25 14:17:37.693920: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a990cc00 of size 3072 next 38
# 2023-04-25 14:17:37.693923: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a990d800 of size 256 next 39
# 2023-04-25 14:17:37.693925: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a990d900 of size 256 next 40
# 2023-04-25 14:17:37.693928: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a990da00 of size 3072 next 42
# 2023-04-25 14:17:37.693930: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a990e600 of size 3072 next 43
# 2023-04-25 14:17:37.693934: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a990f200 of size 3072 next 45
# 2023-04-25 14:17:37.693936: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a990fe00 of size 3072 next 47
# 2023-04-25 14:17:37.693939: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9910a00 of size 3072 next 41
# 2023-04-25 14:17:37.693941: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9911600 of size 3072 next 49
# 2023-04-25 14:17:37.693944: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9912200 of size 256 next 51
# 2023-04-25 14:17:37.693946: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9912300 of size 256 next 52
# 2023-04-25 14:17:37.693950: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9912400 of size 3072 next 35
# 2023-04-25 14:17:37.693953: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9913000 of size 3072 next 58
# 2023-04-25 14:17:37.693955: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9913c00 of size 3072 next 53
# 2023-04-25 14:17:37.693960: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9914800 of size 12288 next 54
# 2023-04-25 14:17:37.693965: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9917800 of size 3072 next 61
# 2023-04-25 14:17:37.693971: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9918400 of size 3072 next 62
# 2023-04-25 14:17:37.693975: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9919000 of size 3072 next 64
# 2023-04-25 14:17:37.693981: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9919c00 of size 3072 next 66
# 2023-04-25 14:17:37.693986: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a991a800 of size 3072 next 60
# 2023-04-25 14:17:37.693991: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a991b400 of size 3072 next 68
# 2023-04-25 14:17:37.693996: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a991c000 of size 3072 next 50
# 2023-04-25 14:17:37.694001: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a991cc00 of size 3072 next 71
# 2023-04-25 14:17:37.694007: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a991d800 of size 3072 next 74
# 2023-04-25 14:17:37.694012: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a991e400 of size 12288 next 76
# 2023-04-25 14:17:37.694018: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9921400 of size 3072 next 78
# 2023-04-25 14:17:37.694023: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9922000 of size 3072 next 79
# 2023-04-25 14:17:37.694029: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9922c00 of size 3055360 next 34
# 2023-04-25 14:17:37.694035: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9c0cb00 of size 2359296 next 55
# 2023-04-25 14:17:37.694040: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73a9e4cb00 of size 2359296 next 44
# 2023-04-25 14:17:37.694046: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73aa08cb00 of size 2359296 next 46
# 2023-04-25 14:17:37.694051: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73aa2ccb00 of size 2359296 next 70
# 2023-04-25 14:17:37.694057: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73aa50cb00 of size 2359296 next 73
# 2023-04-25 14:17:37.694062: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73aa74cb00 of size 2359296 next 63
# 2023-04-25 14:17:37.694064: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73aa98cb00 of size 2359296 next 65
# 2023-04-25 14:17:37.694067: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73aabccb00 of size 2359296 next 89
# 2023-04-25 14:17:37.694069: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73aae0cb00 of size 2359296 next 67
# 2023-04-25 14:17:37.694073: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73ab04cb00 of size 2359296 next 80
# 2023-04-25 14:17:37.694076: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73ab28cb00 of size 2359296 next 84
# 2023-04-25 14:17:37.694078: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73ab4ccb00 of size 3154944 next 77
# 2023-04-25 14:17:37.694081: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73ab7cef00 of size 3072 next 83
# 2023-04-25 14:17:37.694083: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73ab7cfb00 of size 3072 next 86
# 2023-04-25 14:17:37.694086: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73ab7d0700 of size 3072 next 69
# 2023-04-25 14:17:37.694088: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73ab7d1300 of size 3072 next 82
# 2023-04-25 14:17:37.694091: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73ab7d1f00 of size 3072 next 81
# 2023-04-25 14:17:37.694093: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73ab7d2b00 of size 3072 next 92
# 2023-04-25 14:17:37.694096: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73ab7d3700 of size 3072 next 87
# 2023-04-25 14:17:37.694098: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73ab7d4300 of size 3072 next 102
# 2023-04-25 14:17:37.694102: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73ab7d4f00 of size 3072 next 88
# 2023-04-25 14:17:37.694104: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73ab7d5b00 of size 3072 next 94
# 2023-04-25 14:17:37.694107: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73ab7d6700 of size 3072 next 95
# 2023-04-25 14:17:37.694112: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73ab7d7300 of size 3072 next 97
# 2023-04-25 14:17:37.694117: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f73ab7d7f00 of size 3072 next 99
# ...
# 2023-04-25 14:17:37.695989: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 2 Chunks of size 6400 totalling 12.5KiB
# 2023-04-25 14:17:37.695992: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 2 Chunks of size 8448 totalling 16.5KiB
# 2023-04-25 14:17:37.695995: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 34 Chunks of size 12288 totalling 408.0KiB
# 2023-04-25 14:17:37.695998: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 12800 totalling 12.5KiB
# 2023-04-25 14:17:37.696001: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 16384 totalling 16.0KiB
# 2023-04-25 14:17:37.696005: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 2 Chunks of size 16896 totalling 33.0KiB
# 2023-04-25 14:17:37.696008: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 18432 totalling 18.0KiB
# 2023-04-25 14:17:37.696011: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 2 Chunks of size 20224 totalling 39.5KiB
# 2023-04-25 14:17:37.696014: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 2 Chunks of size 25344 totalling 49.5KiB
# 2023-04-25 14:17:37.696018: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 3 Chunks of size 32768 totalling 96.0KiB
# 2023-04-25 14:17:37.696021: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 6 Chunks of size 33024 totalling 193.5KiB
# 2023-04-25 14:17:37.696025: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 67584 totalling 66.0KiB
# 2023-04-25 14:17:37.696028: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 80128 totalling 78.2KiB
# 2023-04-25 14:17:37.696032: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 200192 totalling 195.5KiB
# 2023-04-25 14:17:37.696035: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 2 Chunks of size 400384 totalling 782.0KiB
# 2023-04-25 14:17:37.696038: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 524288 totalling 512.0KiB
# 2023-04-25 14:17:37.696041: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 47 Chunks of size 1179648 totalling 52.88MiB
# 2023-04-25 14:17:37.696044: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 2336256 totalling 2.23MiB
# 2023-04-25 14:17:37.696047: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 143 Chunks of size 2359296 totalling 321.75MiB
# 2023-04-25 14:17:37.696050: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 3055360 totalling 2.91MiB
# 2023-04-25 14:17:37.696054: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 3 Chunks of size 3148800 totalling 9.01MiB
# 2023-04-25 14:17:37.696057: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 3154944 totalling 3.01MiB
# 2023-04-25 14:17:37.696060: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 4706304 totalling 4.49MiB
# 2023-04-25 14:17:37.696063: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 4712448 totalling 4.49MiB
# 2023-04-25 14:17:37.696066: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 24 Chunks of size 4718592 totalling 108.00MiB
# 2023-04-25 14:17:37.696070: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 6297600 totalling 6.01MiB
# 2023-04-25 14:17:37.696073: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 68 Chunks of size 9437184 totalling 612.00MiB
# 2023-04-25 14:17:37.696076: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 11400192 totalling 10.87MiB
# 2023-04-25 14:17:37.696080: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 11784192 totalling 11.24MiB
# 2023-04-25 14:17:37.696083: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 2 Chunks of size 12582912 totalling 24.00MiB
# 2023-04-25 14:17:37.696087: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 10 Chunks of size 12595200 totalling 120.12MiB
# 2023-04-25 14:17:37.696090: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 15725568 totalling 15.00MiB
# 2023-04-25 14:17:37.696094: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 16515072 totalling 15.75MiB
# 2023-04-25 14:17:37.696097: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 18892800 totalling 18.02MiB
# 2023-04-25 14:17:37.696101: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 7 Chunks of size 25190400 totalling 168.16MiB
# 2023-04-25 14:17:37.696104: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 4 Chunks of size 50380800 totalling 192.19MiB
# 2023-04-25 14:17:37.696108: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 201720064 totalling 192.38MiB
# 2023-04-25 14:17:37.696111: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 224242176 totalling 213.85MiB
# 2023-04-25 14:17:37.696116: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 830472192 totalling 792.00MiB
# 2023-04-25 14:17:37.696119: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 3315597312 totalling 3.09GiB
# 2023-04-25 14:17:37.696122: I tensorflow/tsl/framework/bfc_allocator.cc:1107] Sum Total of in-use chunks: 5.92GiB
# 2023-04-25 14:17:37.696126: I tensorflow/tsl/framework/bfc_allocator.cc:1109] Total bytes in pool: 6375866368 memory_limit_: 6375866368 available bytes: 0 curr_region_allocation_bytes_: 12751732736
# 2023-04-25 14:17:37.696133: I tensorflow/tsl/framework/bfc_allocator.cc:1114] Stats:
# Limit:                      6375866368
# InUse:                      6360697344
# MaxInUse:                   6360697600
# NumAllocs:                        1672
# MaxAllocSize:               3315597312
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2023-04-25 14:17:37.696152: W tensorflow/tsl/framework/bfc_allocator.cc:497] ****************************************************************************************************
# 2023-04-25 14:17:37.696453: W tensorflow/core/framework/op_kernel.cc:1830] OP_REQUIRES failed at softmax_op_gpu.cu.cc:198 : RESOURCE_EXHAUSTED: OOM when allocating tensor with shape[8,12,1025,1025] and type half on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 2023-04-25 14:17:37.696494: I tensorflow/core/common_runtime/executor.cc:1197] [/job:localhost/replica:0/task:0/device:GPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): RESOURCE_EXHAUSTED: OOM when allocating tensor with shape[8,12,1025,1025] and type half on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[{{node vi_t_multi_input_multi_output_model/vit-b16/Transformer/encoderblock_1/MultiHeadDotProductAttention_1/Softmax}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# Cell In[3], line 33
#      26 model_3.compile(
#      27     optimizer='adam',
#      28     loss=tf.keras.losses.categorical_crossentropy,
#      29     metrics=['accuracy']
#      30 )
#      32 # Fit the model
# ---> 33 history_3 = model_3.fit(
#      34     train_dataset,
#      35     validation_data=val_dataset,
#      36     epochs=20,
#      37     batch_size=8,
#      38     validation_batch_size=8,
#      39     callbacks=[tensorboard_callback,checkpoint_callback]
#      40 )
#
# File /usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/execute.py:52, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50 try:
#      51   ctx.ensure_initialized()
# ---> 52   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                       inputs, attrs, num_outputs)
#      54 except core._NotOkStatusException as e:
#      55   if name is not None:
#
# ResourceExhaustedError: Graph execution error:
#
# Detected at node 'vi_t_multi_input_multi_output_model/vit-b16/Transformer/encoderblock_1/MultiHeadDotProductAttention_1/Softmax' defined at (most recent call last):
#     File "/usr/lib/python3.8/runpy.py", line 194, in _run_module_as_main
#       return _run_code(code, main_globals, None,
#     File "/usr/lib/python3.8/runpy.py", line 87, in _run_code
#       exec(code, run_globals)
#     File "/usr/local/lib/python3.8/dist-packages/ipykernel_launcher.py", line 17, in <module>
#       app.launch_new_instance()
#     File "/usr/local/lib/python3.8/dist-packages/traitlets/config/application.py", line 1043, in launch_instance
#       app.start()
#     File "/usr/local/lib/python3.8/dist-packages/ipykernel/kernelapp.py", line 725, in start
#       self.io_loop.start()
#     File "/usr/local/lib/python3.8/dist-packages/tornado/platform/asyncio.py", line 215, in start
#       self.asyncio_loop.run_forever()
#     File "/usr/lib/python3.8/asyncio/base_events.py", line 570, in run_forever
#       self._run_once()
#     File "/usr/lib/python3.8/asyncio/base_events.py", line 1859, in _run_once
#       handle._run()
#     File "/usr/lib/python3.8/asyncio/events.py", line 81, in _run
#       self._context.run(self._callback, *self._args)
#     File "/usr/local/lib/python3.8/dist-packages/ipykernel/kernelbase.py", line 513, in dispatch_queue
#       await self.process_one()
#     File "/usr/local/lib/python3.8/dist-packages/ipykernel/kernelbase.py", line 502, in process_one
#       await dispatch(*args)
#     File "/usr/local/lib/python3.8/dist-packages/ipykernel/kernelbase.py", line 409, in dispatch_shell
#       await result
#     File "/usr/local/lib/python3.8/dist-packages/ipykernel/kernelbase.py", line 729, in execute_request
#       reply_content = await reply_content
#     File "/usr/local/lib/python3.8/dist-packages/ipykernel/ipkernel.py", line 422, in do_execute
#       res = shell.run_cell(
#     File "/usr/local/lib/python3.8/dist-packages/ipykernel/zmqshell.py", line 540, in run_cell
#       return super().run_cell(*args, **kwargs)
#     File "/usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py", line 2961, in run_cell
#       result = self._run_cell(
#     File "/usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py", line 3016, in _run_cell
#       result = runner(coro)
#     File "/usr/local/lib/python3.8/dist-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#       coro.send(None)
#     File "/usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py", line 3221, in run_cell_async
#       has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     File "/usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py", line 3400, in run_ast_nodes
#       if await self.run_code(code, result, async_=asy):
#     File "/usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py", line 3460, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "/tmp/ipykernel_3098/2142451117.py", line 33, in <module>
#       history_3 = model_3.fit(
#     File "/usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "/usr/local/lib/python3.8/dist-packages/keras/engine/training.py", line 1685, in fit
#       tmp_logs = self.train_function(iterator)
#     File "/usr/local/lib/python3.8/dist-packages/keras/engine/training.py", line 1284, in train_function
#       return step_function(self, iterator)
#     File "/usr/local/lib/python3.8/dist-packages/keras/engine/training.py", line 1268, in step_function
#       outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/usr/local/lib/python3.8/dist-packages/keras/engine/training.py", line 1249, in run_step
#       outputs = model.train_step(data)
#     File "/usr/local/lib/python3.8/dist-packages/keras/engine/training.py", line 1050, in train_step
#       y_pred = self(x, training=True)
#     File "/usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "/usr/local/lib/python3.8/dist-packages/keras/engine/training.py", line 558, in __call__
#       return super().__call__(*args, **kwargs)
#     File "/usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "/usr/local/lib/python3.8/dist-packages/keras/engine/base_layer.py", line 1145, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "/usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py", line 96, in error_handler
#       return fn(*args, **kwargs)
#     File "/tmp/ipykernel_3098/4264787031.py", line 38, in call
#       x = self.vit_model(image)
#     File "/usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "/usr/local/lib/python3.8/dist-packages/keras/engine/training.py", line 558, in __call__
#       return super().__call__(*args, **kwargs)
#     File "/usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "/usr/local/lib/python3.8/dist-packages/keras/engine/base_layer.py", line 1145, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "/usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py", line 96, in error_handler
#       return fn(*args, **kwargs)
#     File "/usr/local/lib/python3.8/dist-packages/keras/engine/functional.py", line 512, in call
#       return self._run_internal_graph(inputs, training=training, mask=mask)
#     File "/usr/local/lib/python3.8/dist-packages/keras/engine/functional.py", line 669, in _run_internal_graph
#       outputs = node.layer(*args, **kwargs)
#     File "/usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "/usr/local/lib/python3.8/dist-packages/keras/engine/base_layer.py", line 1145, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "/usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py", line 96, in error_handler
#       return fn(*args, **kwargs)
#     File "/usr/local/lib/python3.8/dist-packages/vit_keras/layers.py", line 169, in call
#       x, weights = self.att(x)
#     File "/usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "/usr/local/lib/python3.8/dist-packages/keras/engine/base_layer.py", line 1145, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "/usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py", line 96, in error_handler
#       return fn(*args, **kwargs)
#     File "/usr/local/lib/python3.8/dist-packages/vit_keras/layers.py", line 107, in call
#       attention, weights = self.attention(query, key, value)
#     File "/usr/local/lib/python3.8/dist-packages/vit_keras/layers.py", line 90, in attention
#       weights = tf.nn.softmax(scaled_score, axis=-1)
# Node: 'vi_t_multi_input_multi_output_model/vit-b16/Transformer/encoderblock_1/MultiHeadDotProductAttention_1/Softmax'
# OOM when allocating tensor with shape[8,12,1025,1025] and type half on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[{{node vi_t_multi_input_multi_output_model/vit-b16/Transformer/encoderblock_1/MultiHeadDotProductAttention_1/Softmax}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#  [Op:__inference_train_function_51461]
